# %%
# Clone your repository
# !git clone https://github.com/COSMIC-ATOM97/ANPR-API.git
# %cd ANPR-API

# Install requirements
# !pip install -q torch torchvision ultralytics transformers opencv-python Pillow numpy matplotlib datasets accelerate

# Check GPU
import torch
print(f"🚀 CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"🎮 GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Cloning into 'ANPR-API'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'ANPR-API'
# /content
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/COSMIC-ATOM97/ANPR-API.git
# %cd ANPR-API
# Out:
# Cloning into 'ANPR-API'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 48 (delta 4), reused 46 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 28.39 MiB | 28.42 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/ANPR-API

# %%
# Update these variables with your actual file names
IMAGE_NAME = "TEST.jpeg"  # Change to your image name
MODEL_PATH = "models/best.pt"  # Change if your model has different name

# Run ANPR with TrOCR
# !python run_anpr_trocr.py --yolo_model {MODEL_PATH} --input {IMAGE_NAME}
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751364444.872128    3206 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751364444.884438    3206 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🚀 Initializing TrOCR ANPR Pipeline...
# 📡 Loading YOLO model...
# 🔤 Loading TrOCR model...
# Using device: cpu
# Loading TrOCR model: microsoft/trocr-base-printed
# preprocessor_config.json: 100% 224/224 [00:00<00:00, 1.22MB/s]
# ...

# %%
# Try with larger model for better accuracy
print("🔄 Trying with large TrOCR model...")
# !python run_anpr_trocr.py --yolo_model {MODEL_PATH} --input {IMAGE_NAME} --trocr_model microsoft/trocr-large-printed
# Out:
# 🔄 Trying with large TrOCR model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751364545.564267    3893 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751364545.571536    3893 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🚀 Initializing TrOCR ANPR Pipeline...
# 📡 Loading YOLO model...
# 🔤 Loading TrOCR model...
# Using device: cpu
# Loading TrOCR model: microsoft/trocr-large-printed
# preprocessor_config.json: 100% 224/224 [00:00<00:00, 1.04MB/s]
# ...

# %%
# Display results
import glob
from IPython.display import Image, display
import matplotlib.pyplot as plt

# Show extracted plates
print("🔍 Extracted License Plates:")
plate_files = glob.glob("extracted_plate_*.jpg") + glob.glob("large_plate_*.jpg")

for i, plate_file in enumerate(plate_files[:6]):
    print(f"\n📋 Plate {i+1}: {plate_file}")
    display(Image(plate_file))

# Show final results
print("\n🎯 Final ANPR Results:")
result_files = glob.glob("trocr_anpr_result_*.jpg")
for result_file in result_files[-3:]:
    print(f"\n📸 {result_file}")
    display(Image(result_file))
# Out:
# 🔍 Extracted License Plates:
#
# 📋 Plate 1: extracted_plate_20250701_100807_1.jpg
# 📋 Plate 2: extracted_plate_20250701_152238_1.jpg
# 📋 Plate 3: extracted_plate_20250701_100957_1.jpg
# 📋 Plate 4: large_plate_20250701_100957_1.jpg
# 📋 Plate 5: large_plate_20250701_100807_1.jpg
# 🎯 Final ANPR Results:
#
# 📸 trocr_anpr_result_20250701_100815.jpg
# 📸 trocr_anpr_result_20250701_101013.jpg

# %%
# Create zip file and download
# !zip -r anpr_results.zip extracted_plate_*.jpg large_plate_*.jpg trocr_anpr_result_*.jpg

from google.colab import files
files.download('anpr_results.zip')
print("✅ Results downloaded!")
# Out:
#   adding: extracted_plate_20250701_100807_1.jpg (deflated 4%)
#   adding: extracted_plate_20250701_100957_1.jpg (deflated 4%)
#   adding: extracted_plate_20250701_152238_1.jpg (deflated 4%)
#   adding: large_plate_20250701_100807_1.jpg (deflated 2%)
#   adding: large_plate_20250701_100957_1.jpg (deflated 2%)
#   adding: trocr_anpr_result_20250701_100815.jpg (deflated 1%)
#   adding: trocr_anpr_result_20250701_101013.jpg (deflated 1%)
# ✅ Results downloaded!
